# %%
from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("{이것}은 무엇을 의미하니?")

llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.1",
    huggingfacehub_api_token="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",
    model_kwargs={
        "max_new_tokens":250
    }
)

chain = prompt | llm

chain.invoke({
    "이것":"락앤롤"
})
# Out:
# /Users/eunkyo/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/models/mistralai/Mistral-7B-Instruct-v0.1
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[7], line 6
#       2 from langchain.prompts import PromptTemplate
#       4 prompt = PromptTemplate.from_template("{이것}은 무엇을 의미하니?")
# ----> 6 llm = HuggingFaceHub(
#       7     repo_id="mistralai/Mistral-7B-Instruct-v0.1",
#       8     huggingfacehub_api_token="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",
#       9     model_kwargs={
#      10         "max_new_tokens":250
#      11     }
#      12 )
#      14 chain = prompt | llm
#      16 chain.invoke({
#      17     "이것":"락앤롤"
#      18 })
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/langchain/load/serializable.py:97, in Serializable.__init__(self, **kwargs)
#      96 def __init__(self, **kwargs: Any) -> None:
# ---> 97     super().__init__(**kwargs)
#      98     self._lc_kwargs = kwargs
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/pydantic/main.py:339, in pydantic.main.BaseModel.__init__()
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/pydantic/main.py:1102, in pydantic.main.validate_model()
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/langchain/llms/huggingface_hub.py:55, in HuggingFaceHub.validate_environment(cls, values)
#      52 from huggingface_hub.inference_api import InferenceApi
#      54 repo_id = values["repo_id"]
# ---> 55 client = InferenceApi(
#      56     repo_id=repo_id,
#      57     token=huggingfacehub_api_token,
#      58     task=values.get("task"),
#      59 )
#      60 if client.task not in VALID_TASKS:
#      61     raise ValueError(
#      62         f"Got invalid task {client.task}, "
#      63         f"currently only {VALID_TASKS} are supported"
#      64     )
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:132, in _deprecate_method.<locals>._inner_deprecate_method.<locals>.inner_f(*args, **kwargs)
#     130     warning_message += " " + message
#     131 warnings.warn(warning_message, FutureWarning)
# --> 132 return f(*args, **kwargs)
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/inference_api.py:131, in InferenceApi.__init__(self, repo_id, task, token, gpu)
#     128 self.headers = build_hf_headers(token=token)
#     130 # Configure task
# --> 131 model_info = HfApi(token=token).model_info(repo_id=repo_id)
#     132 if not model_info.pipeline_tag and not task:
#     133     raise ValueError(
#     134         "Task not specified in the repository. Please add it to the model card"
#     135         " using pipeline_tag"
#     136         " (https://huggingface.co/docs#how-is-a-models-type-of-inference-api-and-widget-determined)"
#     137     )
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/hf_api.py:2301, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, token)
#    2299     params["blobs"] = True
#    2300 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 2301 hf_raise_for_status(r)
#    2302 data = r.json()
#    2303 return ModelInfo(**data)
#
# File ~/gitProject/fullGPT/env/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:367, in hf_raise_for_status(response, endpoint_name)
#     360 elif response.status_code == 403:
#     361     message = (
#     362         f"\n\n{response.status_code} Forbidden: {error_message}."
#     363         + f"\nCannot access content at: {response.url}."
#     364         + "\nIf you are trying to create or update content,"
#     365         + "make sure you have a token with the `write` role."
#     366     )
# --> 367     raise HfHubHTTPError(message, response=response) from e
#     369 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     370 # as well (request id and/or server error message)
#     371 raise HfHubHTTPError(str(e), response=response) from e
#
# HfHubHTTPError:  (Request ID: Root=1-6661bf94-3f5b1d3f0b93b5e66bb4cc84;4456a8e5-84fe-44b2-8442-9d9d0151c238)
#
# 403 Forbidden: Authorization error..
# Cannot access content at: https://huggingface.co/api/models/mistralai/Mistral-7B-Instruct-v0.1.
# If you are trying to create or update content,make sure you have a token with the `write` role.
